# %%
print("Hello, World".upper())
# Out:
# HELLO, WORLD

# %%
major = str(input("Plases enter your major : ")).lower()
gender = str(input("Plases enter your gender : ")).lower()
x= gender.find("f")
y= major.find("eng")

if y>=0:
    if x>=0 :
        print("You are a woderful Eng!!<3")
    else:
        print("sorry ")
else:
    print("sorryx2")
# Out:
# Plases enter your major :  eng
# Plases enter your gender :  female
# You are a woderful Eng!!<3
